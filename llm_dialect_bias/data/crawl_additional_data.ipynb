# %%
from datasets import load_dataset
dataset = load_dataset("rlitschk/wikidir", cache_dir='/work/bbc6523/cache_dir')
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]Failed to load JSON from file '/home/bbc6523/.cache/huggingface/hub/datasets--rlitschk--wikidir/snapshots/8ad8a44f5fb14886a5736e3844c4e60c1635e128/de.als/train.jsonl' with error <class 'pyarrow.lib.ArrowInvalid'>: JSON parse error: Column(/tgt_results/[]/[]) changed from string to number in row 0
# Generating train split: 0 examples [00:00, ? examples/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /work/bbc6523/miniforge3/envs/cultural/lib/python3.10/site-packages/datasets/packaged_modules/json/json.py:160, in Json._generate_tables(self, files)
#     157     with open(
#     158         file, encoding=self.config.encoding, errors=self.config.encoding_errors
#     159     ) as f:
# --> 160         df = pandas_read_json(f)
#     161 except ValueError:
#
# ...
